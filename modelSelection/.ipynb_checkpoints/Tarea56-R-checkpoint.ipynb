# %%
library(MASS)
library(glmnet)
library(leaps)
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 3.0-2

# %%
#Boston$rad=as.numeric(Boston$rad)
#Boston$chas=as.factor(Boston$chas)
#str(Boston)
#attach(Boston)
Data = Boston
mod1 = lm(crim ~ . ^2,data=Data)
trans = boxcox(mod1)
lambda = trans$x[trans$y == max(trans$y)]
Data$crim = (Data$crim^lambda -1) / lambda
# Out:
# plot without title

# %%
x = model.matrix(log(medv) ~ .^2 , Boston)
y = log(Boston$medv)
# Out:
# [1] 0.02020202

# %%
mod1 = lm(crim ~ . ^2,data=Boston)

# %%
summary(mod1)
# Out:
# Call:
# lm(formula = crim ~ .^2, data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -17.981  -1.243  -0.059   0.923  62.090
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -1.171e+01  1.483e+02  -0.079 0.937096
# zn             4.307e-01  8.953e-01   0.481 0.630740
# indus         -2.164e+00  3.298e+00  -0.656 0.511947
# chas1          1.274e+01  4.348e+01   0.293 0.769725
# nox           -1.891e+00  1.460e+02  -0.013 0.989671
# rm            -2.217e+00  1.688e+01  -0.131 0.895599
# age            1.153e+00  5.184e-01   2.223 0.026730 *
# dis            4.911e+00  8.464e+00   0.580 0.562052
# rad            6.192e-01  4.830e+00   0.128 0.898065
# tax            5.197e-02  2.827e-01   0.184 0.854242
# ptratio        1.743e-01  6.135e+00   0.028 0.977355
# black         -2.074e-01  1.498e-01  -1.385 0.166923
# lstat          2.423e+00  1.826e+00   1.327 0.185184
# medv          -3.337e-01  1.673e+00  -0.199 0.841970
# ...

# %%
mod2 = step(mod1,k=2)
# Out:
# Start:  AIC=1813.35
# crim ~ (zn + indus + chas + nox + rm + age + dis + rad + tax +
#     ptratio + black + lstat + medv)^2
#
#                 Df Sum of Sq   RSS    AIC
# - rm:age         1      0.00 12665 1811.3
# - age:tax        1      0.00 12665 1811.3
# - indus:medv     1      0.03 12665 1811.3
# - zn:chas        1      0.05 12665 1811.3
# - chas:rad       1      0.06 12665 1811.4
# - indus:rad      1      0.09 12665 1811.4
# - zn:ptratio     1      0.15 12665 1811.4
# - tax:lstat      1      0.22 12665 1811.4
# - tax:medv       1      0.23 12665 1811.4
# - chas:lstat     1      0.28 12665 1811.4
# - indus:ptratio  1      0.41 12666 1811.4
# - indus:dis      1      0.52 12666 1811.4
# - rm:tax         1      0.55 12666 1811.4
# - ptratio:black  1      0.64 12666 1811.4
# - nox:lstat      1      0.68 12666 1811.4
# - zn:tax         1      0.69 12666 1811.4
# - dis:ptratio    1      0.69 12666 1811.4
# - zn:dis         1      0.73 12666 1811.4
# ...

# %%
summary(mod2)
# Out:
# Call:
# lm(formula = crim ~ zn + chas + nox + rm + age + dis + rad +
#     tax + black + lstat + medv + zn:rad + zn:black + chas:rm +
#     chas:medv + nox:tax + rm:dis + rm:black + rm:lstat + rm:medv +
#     age:rad + age:black + age:lstat + dis:rad + dis:medv + rad:black +
#     rad:lstat + rad:medv + tax:black + black:lstat + black:medv +
#     lstat:medv, data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -17.367  -1.348  -0.178   1.034  63.246
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.778e+01  3.197e+01  -0.869 0.385384
# zn           6.760e-01  3.513e-01   1.924 0.054909 .
# chas1        2.007e+01  8.353e+00   2.403 0.016651 *
# nox          3.778e+01  1.296e+01   2.915 0.003727 **
# rm          -2.805e+00  3.105e+00  -0.903 0.366762
# age          8.917e-01  1.292e-01   6.899 1.68e-11 ***
# dis          5.886e+00  2.026e+00   2.906 0.003833 **
# rad          4.630e+00  9.701e-01   4.773 2.42e-06 ***
# ...

# %%
mod3 = step(mod1,k=log(dim(Boston)[1]))
# Out:
# Start:  AIC=2202.19
# crim ~ (zn + indus + chas + nox + rm + age + dis + rad + tax +
#     ptratio + black + lstat + medv)^2
#
#                 Df Sum of Sq   RSS    AIC
# - rm:age         1      0.00 12665 2196.0
# - age:tax        1      0.00 12665 2196.0
# - indus:medv     1      0.03 12665 2196.0
# - zn:chas        1      0.05 12665 2196.0
# - chas:rad       1      0.06 12665 2196.0
# - indus:rad      1      0.09 12665 2196.0
# - zn:ptratio     1      0.15 12665 2196.0
# - tax:lstat      1      0.22 12665 2196.0
# - tax:medv       1      0.23 12665 2196.0
# - chas:lstat     1      0.28 12665 2196.0
# - indus:ptratio  1      0.41 12666 2196.0
# - indus:dis      1      0.52 12666 2196.0
# - rm:tax         1      0.55 12666 2196.0
# - ptratio:black  1      0.64 12666 2196.0
# - nox:lstat      1      0.68 12666 2196.0
# - zn:tax         1      0.69 12666 2196.0
# - dis:ptratio    1      0.69 12666 2196.0
# - zn:dis         1      0.73 12666 2196.0
# ...

# %%
summary(mod3)
# Out:
# Call:
# lm(formula = crim ~ zn + nox + rm + age + dis + rad + tax + black +
#     lstat + medv + zn:rad + nox:tax + rm:black + age:black +
#     dis:rad + rad:lstat + rad:medv + black:lstat + lstat:medv,
#     data = Boston)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -17.794  -1.320  -0.179   0.915  65.965
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.742e+01  1.740e+01  -1.001 0.317264
# zn          -9.260e-02  3.081e-02  -3.005 0.002792 **
# nox          4.082e+01  1.230e+01   3.317 0.000978 ***
# rm          -8.318e+00  1.709e+00  -4.869 1.52e-06 ***
# age          5.269e-01  9.910e-02   5.317 1.61e-07 ***
# dis          1.495e+00  3.499e-01   4.274 2.32e-05 ***
# rad          2.435e+00  2.960e-01   8.227 1.78e-15 ***
# tax          5.610e-02  1.476e-02   3.802 0.000162 ***
# black       -4.680e-02  3.962e-02  -1.181 0.238094
# lstat        1.395e-01  2.432e-01   0.574 0.566505
# ...

# %%
# Out:
# plot without title

# %%
# Out:
# plot without title

# %%
Data$chas = as.numeric(Data$chas)

# %%
Data
# Out:
#     crim         zn   indus chas nox   rm    age   dis    rad tax ptratio
# 1   -4.813613147 18.0 2.31  1    0.538 6.575  65.2 4.0900 1   296 15.3
# 2   -3.472674695  0.0 7.07  1    0.469 6.421  78.9 4.9671 2   242 17.8
# 3   -3.473355895  0.0 7.07  1    0.469 7.185  61.1 4.9671 2   242 17.8
# 4   -3.314348772  0.0 2.18  1    0.458 6.998  45.8 6.0622 3   222 18.7
# 5   -2.602039101  0.0 2.18  1    0.458 7.147  54.2 6.0622 3   222 18.7
# 6   -3.389907485  0.0 2.18  1    0.458 6.430  58.7 6.0622 3   222 18.7
# 7   -2.368584613 12.5 7.87  1    0.524 6.012  66.6 5.5605 5   311 15.2
# 8   -1.896830742 12.5 7.87  1    0.524 6.172  96.1 5.9505 5   311 15.2
# 9   -1.530597029 12.5 7.87  1    0.524 5.631 100.0 6.0821 5   311 15.2
# 10  -1.740389461 12.5 7.87  1    0.524 6.004  85.9 6.5921 5   311 15.2
# 11  -1.469878341 12.5 7.87  1    0.524 6.377  94.3 6.3467 5   311 15.2
# 12  -2.095906641 12.5 7.87  1    0.524 6.009  82.9 6.2267 5   311 15.2
# ...

# %%
scale(Boston$crim)
# Out:
#       [,1]
#  [1,] -0.4193669
#  [2,] -0.4169267
#  [3,] -0.4169290
#  [4,] -0.4163384
#  [5,] -0.4120741
#  [6,] -0.4166314
#  [7,] -0.4098372
#  [8,] -0.4032966
#  [9,] -0.3955433
# [10,] -0.4003331
# [11,] -0.3939564
# [12,] -0.4064448
# [13,] -0.4091990
# [14,] -0.3468869
# [15,] -0.3459336
# [16,] -0.3471625
# [17,] -0.2975737
# [18,] -0.3289320
# [19,] -0.3267801
# [20,] -0.3357215
# [21,] -0.2745709
# [22,] -0.3210451
# [23,] -0.2768170
# [24,] -0.3051886
# [25,] -0.3328778
# [26,] -0.3223820
# [27,] -0.3419866
# [28,] -0.3089856
# [29,] -0.3302353
# [30,] -0.3035587
# [31,] ⋮
# [32,]  0.146239592
# [33,]  1.326491497
# [34,]  0.769568300
# [35,]  1.246308229
# [36,]  0.256987136
# [37,]  0.243520951
# [38,]  0.246192564
# [39,] -0.092441945
# [40,] -0.143573456
# [41,]  0.006992516
# [42,]  0.241610829
# [43,]  0.142084524
# [44,] -0.402562972
# [45,] -0.398783418
# [46,] -0.395982758
# [47,] -0.407808541
# [48,] -0.407159820
# [49,] -0.399952975
# [50,] -0.387599381
# ...
