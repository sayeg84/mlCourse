# %% [markdown]
# ## Librerias y definiciones necesarias

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api  as smf
import os
if not(os.path.isdir("tarea")):
    mkdir("tarea")
    
def cleanVarName(var):
    if len(var) > 1:
        if var[0]=="C" and var[1]=="(":
            if len(var.split("[")) > 1:
                return var.split(",")[0][2:] + " [" + var.split("[")[1]
            else:
                return var.split(",")[0][2:] 
        elif len(var.split(":")) > 1:
            fin = ""
            for v in var.split(":"):
                fin += " : " + v 
            return fin
        else:
            return var
    else:
        return var
def significanceTable(fit):
    df = pd.DataFrame(columns = ["R-squared",
                                 "AIC",
                                 "BIC",
                                 "Log-Likelihood",
                                "F-statistic",
                                "Prob (F-statistic)"])
    df.loc[0]=[fit.rsquared,
    fit.aic,
    fit.bic,
    fit.llf,
    fit.fvalue,
    fit.f_pvalue]
    return df
def coefficientTable(fit):
    df = fit.summary2().tables[1]
    df = df.rename(columns={"P>|t|":"$P (> |t|)$"})
    
    df.index = [cleanVarName(var) for var in df.index]
    return df
def anovaTable(fit):
    df = sm.stats.anova_lm(fit)
    df = df.rename(columns={"PR(>F)":"$P (> F$)"})
    df.index = [cleanVarName(var) for var in df.index]
    df.index.name = "Variable"
    return df 
def comparisonTable(fits):
    dfs = [significanceTable(fit) for fit in fits]
    df = dfs[0]
    for i in range(1,len(dfs)):
        df.loc[i] = dfs[i].iloc[0]
    formulas = [fit.model.formula for fit in fits]
    df.insert(loc=0,column="Model",value=formulas)
    return df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cdcbf137f158> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 import statsmodels.api as sm
#       5 import statsmodels.formula.api  as smf
#       6 import os
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# ## Ejercicio 1. Problema 10

# %%
df = pd.read_csv("carseats.csv",header=0)
df.head().to_latex(buf = os.path.join("tarea","1-data.tex"))

# %%
fit = smf.ols(formula="Sales ~ Price + C(Urban) + C(US)",
              data=df).fit()
print(fit.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c858d9ea0c20> in <module>
# ----> 1 fit = smf.ols(formula="Sales ~ Price + C(Urban) + C(US)",
#       2               data=df).fit()
#       3 print(fit.summary())
#
# NameError: name 'smf' is not defined

# %%
coefficientTable(fit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-02338d8fe71d> in <module>
# ----> 1 coefficientTable(fit)
#
# NameError: name 'coefficientTable' is not defined

# %%
coefficientTable(fit).to_latex(buf=os.path.join("tarea","1-mod1.tex"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-287ba78138f2> in <module>
# ----> 1 coefficientTable(fit).to_latex(buf=os.path.join("tarea","1-mod1.tex"))
#
# NameError: name 'coefficientTable' is not defined

# %%
fit2 = smf.ols(
    formula="Sales ~ Price + C(US)",
    data=df).fit()
print(fit2.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-42037b37d4d3> in <module>
# ----> 1 fit2 = smf.ols(
#       2     formula="Sales ~ Price + C(US)",
#       3     data=df).fit()
#       4 print(fit2.summary())
#
# NameError: name 'smf' is not defined

# %%
coefficientTable(fit2).to_latex(buf="tarea/1-mod2.tex")
comparisonTable([fit,fit2]).to_latex(buf="tarea/1-modCompar.tex")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-273a67bc1294> in <module>
# ----> 1 coefficientTable(fit2).to_latex(buf="tarea/1-mod2.tex")
#       2 comparisonTable([fit,fit2]).to_latex(buf="tarea/1-modCompar.tex")
#
# NameError: name 'coefficientTable' is not defined

# %%
abs(fit.rsquared - fit2.rsquared)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3f095119ace9> in <module>
# ----> 1 abs(fit.rsquared - fit2.rsquared)
#
# NameError: name 'fit' is not defined

# %%
print(fit2.conf_int(alpha = 0.05))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-05a77963a29f> in <module>
# ----> 1 print(fit2.conf_int(alpha = 0.05))
#
# NameError: name 'fit2' is not defined

# %%
a=0.5
fig = plt.figure(figsize=(6,4))
plt.scatter(fit2.predict(),fit2.resid.tolist(),alpha = a)
plt.ylabel("Residuals")
plt.xlabel("Fitted Sales")
plt.title("Residual Plot")
plt.grid()
plt.tight_layout()
plt.savefig("tarea/1-resplot.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6841d33a92b9> in <module>
#       1 a=0.5
#       2 fig = plt.figure(figsize=(6,4))
# ----> 3 plt.scatter(fit2.predict(),fit2.resid.tolist(),alpha = a)
#       4 plt.ylabel("Residuals")
#       5 plt.xlabel("Fitted Sales")
#
# NameError: name 'fit2' is not defined

# %%
fig = plt.figure(figsize=(10,4))
n = len(fit2.resid.tolist())
plt.scatter(range(n),fit2.resid.tolist(), alpha = a)
plt.plot([0,n],[0,0],c="k",lw=3,ls="--", alpha = a)
plt.ylabel("Residuals")
plt.xlabel("Index")
plt.title("Residual Series")
plt.grid()
plt.tight_layout()
plt.savefig("tarea/1-restimeplot.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e809f3fb4dbb> in <module>
#       1 fig = plt.figure(figsize=(10,4))
# ----> 2 n = len(fit2.resid.tolist())
#       3 plt.scatter(range(n),fit2.resid.tolist(), alpha = a)
#       4 plt.plot([0,n],[0,0],c="k",lw=3,ls="--", alpha = a)
#       5 plt.ylabel("Residuals")
#
# NameError: name 'fit2' is not defined

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_ccpr_grid(fit2,fig=fig)
for ax in fig.axes:
    ax.grid()
fig.suptitle("Component-Component Residuals",x=0.5,y=1.05,fontsize=20,ha="center")
plt.tight_layout()
fig.savefig("tarea/1-compcomp.pdf",bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8f9c6743bf86> in <module>
#       1 fig = plt.figure(figsize=(12,8))
# ----> 2 fig = sm.graphics.plot_ccpr_grid(fit2,fig=fig)
#       3 for ax in fig.axes:
#       4     ax.grid()
#       5 fig.suptitle("Component-Component Residuals",x=0.5,y=1.05,fontsize=20,ha="center")
#
# NameError: name 'sm' is not defined

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(fit2,"Price",fig=fig)
for ax in fig.axes:
    ax.grid()
plt.tight_layout()
plt.savefig("tarea/1-regdiag.pdf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-7e44d832244b> in <module>
#       1 fig = plt.figure(figsize=(12,8))
# ----> 2 fig = sm.graphics.plot_regress_exog(fit2,"Price",fig=fig)
#       3 for ax in fig.axes:
#       4     ax.grid()
#       5 plt.tight_layout()
#
# NameError: name 'sm' is not defined

# %%
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(fit2, ax=ax)
plt.grid()
plt.tight_layout()
plt.savefig("tarea/1-influence.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2b64a578dbaa> in <module>
#       1 fig, ax = plt.subplots(figsize=(12,8))
# ----> 2 fig = sm.graphics.influence_plot(fit2, ax=ax)
#       3 plt.grid()
#       4 plt.tight_layout()
#       5 plt.savefig("tarea/1-influence.pdf")
#
# NameError: name 'sm' is not defined

# %%
sm.graphics.qqplot(fit2.resid)
plt.title("Q-Q plot of predicted values")
plt.grid()
plt.tight_layout()
plt.savefig("tarea/1-qqplot.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b59ab6568006> in <module>
# ----> 1 sm.graphics.qqplot(fit2.resid)
#       2 plt.title("Q-Q plot of predicted values")
#       3 plt.grid()
#       4 plt.tight_layout()
#       5 plt.savefig("tarea/1-qqplot.pdf")
#
# NameError: name 'sm' is not defined

# %%
df.iloc[[42,174,165],:].to_latex(buf="tarea/1-outliers.tex")

# %% [markdown]
# ## Ejercicio 1. Problema 14

# %%
np.random.seed(1)
x1 = np.random.uniform(size=100)
x2 = 0.5*x1 + np.random.randn(100)/10
y = 2 + 2*x1 +0.3*x2 + np.random.randn(100)
df = pd.DataFrame()
df["x1"] = x1
df["x2"] = x2
df["y"] = y
df.head().to_latex(buf="tarea/2-data.tex")
print(df.head())
# Out:
# x1        x2         y
# 0  0.417022  0.240074  2.949735
# 1  0.720324  0.157942  3.261717
# 2  0.000114 -0.030563  3.322517
# 3  0.302333  0.233964  2.387546
# 4  0.146756  0.096387  3.002498

# %%
df.plot.scatter(x="x1",y="x2")
plt.grid()
plt.title(u"Correlación entre x1 y x2")
plt.savefig("tarea/2-corr.pdf")
cor = np.corrcoef(x1,x2)[0][1]
plt.text(0.8,0.0,"R^2={0}".format(round(cor,5)),
         va = "top",
         ha = "center",
    bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
plt.tight_layout()
plt.savefig("tarea/2-corr.pdf")
plt.show()

# %%
formulas = ["y ~ x1 +x2", "y ~ x1", "y ~x2"]
fits = [ smf.ols(formula = form , data=df).fit() for form in formulas] 
for fit in fits:
    print(fit.summary())
    print()
    print()
    print(fit.pvalues)
    print()
    print()
    coefficientTable(fit).to_latex(buf = "tarea/2-mod{0}.tex".format(fits.index(fit)+1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-73a8f969478a> in <module>
#       1 formulas = ["y ~ x1 +x2", "y ~ x1", "y ~x2"]
# ----> 2 fits = [ smf.ols(formula = form , data=df).fit() for form in formulas]
#       3 for fit in fits:
#       4     print(fit.summary())
#       5     print()
#
# <ipython-input-19-73a8f969478a> in <listcomp>(.0)
#       1 formulas = ["y ~ x1 +x2", "y ~ x1", "y ~x2"]
# ----> 2 fits = [ smf.ols(formula = form , data=df).fit() for form in formulas]
#       3 for fit in fits:
#       4     print(fit.summary())
#       5     print()
#
# NameError: name 'smf' is not defined

# %%
comparisonTable(fits).to_latex(buf="tarea/2-modComp.tex",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-76371a27c008> in <module>
# ----> 1 comparisonTable(fits).to_latex(buf="tarea/2-modComp.tex",index=False)
#
# NameError: name 'comparisonTable' is not defined

# %%
df.loc[100] = [0.1,0.8,0.6]
df.tail()
# Out:
#            x1        x2         y
# 96   0.903380  0.386998  4.758863
# 97   0.573679  0.376988  4.803815
# 98   0.002870  0.254268  2.840827
# 99   0.617145  0.283709  4.204311
# 100  0.100000  0.800000  0.600000

# %%
df.iloc[1:100].plot.scatter(x="x1",y="x2",label="data")
plt.scatter([0.1],[0.8],c="C1",label="New point")
plt.legend()
plt.grid()
plt.title("Plano x-y")
plt.tight_layout()
plt.savefig("tarea/2-newData.pdf")
plt.show()

# %%
fit.resid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9de35a887e12> in <module>
# ----> 1 fit.resid
#
# NameError: name 'fit' is not defined

# %%
fits = [ smf.ols(formula = form , data=df).fit() for form in formulas] 
for fit in fits:
    print(fit.summary())
    print()
    print()
    print(fit.pvalues)
    print()
    print()
    print( fit.resid[100] / ( fit.resid.std() / np.sqrt(101) ) )
    coefficientTable(fit).to_latex(buf = "tarea/2-newMod{0}.tex".format(fits.index(fit)+1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-3382d10528af> in <module>
# ----> 1 fits = [ smf.ols(formula = form , data=df).fit() for form in formulas]
#       2 for fit in fits:
#       3     print(fit.summary())
#       4     print()
#       5     print()
#
# <ipython-input-24-3382d10528af> in <listcomp>(.0)
# ----> 1 fits = [ smf.ols(formula = form , data=df).fit() for form in formulas]
#       2 for fit in fits:
#       3     print(fit.summary())
#       4     print()
#       5     print()
#
# NameError: name 'smf' is not defined

# %% [markdown]
# ## Problema 2

# %%
df = pd.read_csv("June_13_data.csv",header=0)
df=df.astype({'year': 'object',"Month":"object","Time_of_Day":"object"})
df
# Out:
#        Crash_Score  year Month Time_of_Day    Rd_Feature    Rd_Character  \
# 0             6.56  2016     6           2          NONE  STRAIGHT-LEVEL
# 1             6.53  2016     6           3          NONE  STRAIGHT-LEVEL
# 2             1.58  2016     6           5          NONE  STRAIGHT-LEVEL
# 3             7.15  2016     6           3          NONE  STRAIGHT-LEVEL
# 4             9.57  2016     6           6          NONE  STRAIGHT-LEVEL
# ...            ...   ...   ...         ...           ...             ...
# 23132         1.80  2018    12           5          NONE  STRAIGHT-LEVEL
# 23133         2.59  2018    12           6  INTERSECTION  STRAIGHT-LEVEL
# 23134         6.95  2018    12           3  INTERSECTION  STRAIGHT-OTHER
# 23135         3.17  2018    12           5          NONE  STRAIGHT-OTHER
# 23136         5.27  2018    12           6  INTERSECTION  STRAIGHT-LEVEL
#
#         Rd_Class            Rd_Configuration      Rd_Surface Rd_Conditions  \
# 0      STATE HWY    TWO-WAY-PROTECTED-MEDIAN  SMOOTH ASPHALT           DRY
# 1          OTHER           TWO-WAY-NO-MEDIAN  COARSE ASPHALT           DRY
# 2      STATE HWY           TWO-WAY-NO-MEDIAN  SMOOTH ASPHALT           DRY
# 3          OTHER           TWO-WAY-NO-MEDIAN  SMOOTH ASPHALT           DRY
# 4          OTHER           TWO-WAY-NO-MEDIAN  COARSE ASPHALT           DRY
# ...          ...                         ...             ...           ...
# 23132  STATE HWY  TWO-WAY-UNPROTECTED-MEDIAN  SMOOTH ASPHALT           DRY
# 23133  STATE HWY  TWO-WAY-UNPROTECTED-MEDIAN  SMOOTH ASPHALT           DRY
# 23134      OTHER  TWO-WAY-UNPROTECTED-MEDIAN  SMOOTH ASPHALT           DRY
# 23135     US HWY    TWO-WAY-PROTECTED-MEDIAN  COARSE ASPHALT           DRY
# 23136  STATE HWY           TWO-WAY-NO-MEDIAN  SMOOTH ASPHALT           DRY
#
#               Light Weather Traffic_Control Work_Area
# 0          DAYLIGHT   CLEAR            NONE        NO
# 1          DAYLIGHT   CLEAR            NONE        NO
# 2      DARK-NOT-LIT   CLEAR            NONE        NO
# 3          DAYLIGHT   CLEAR            NONE        NO
# 4          DARK-LIT   CLEAR            NONE        NO
# ...             ...     ...             ...       ...
# 23132      DARK-LIT   CLEAR            NONE        NO
# 23133          DUSK   CLEAR          SIGNAL        NO
# 23134      DAYLIGHT   CLEAR          SIGNAL        NO
# 23135  DARK-NOT-LIT   CLEAR            NONE        NO
# 23136      DARK-LIT   CLEAR          SIGNAL        NO
#
# [23137 rows x 14 columns]

# %%
par = ["p{2cm}" for i in range(10)]
colFormat = "ccccc"
for p in par:
    colFormat += p
df.head().to_latex(buf="tarea/3-data.tex",column_format=colFormat)

# %%
cols = df.columns.tolist()
for col in cols:
    if col != "Crash_Score":
        nb=30
        fig, ax = plt.subplots(ncols=2,nrows=1,figsize=(12,6))
        df.boxplot(column="Crash_Score",
                           by=col, 
                           fontsize=16,
                           figsize=(10,10),
                           rot = 45,
                           ax = ax[0]
        )
        for value in set(df[col]):
            df[df[col]==value]["Crash_Score"].hist(alpha=0.5,
                                                   ax=ax[1],
                                                   label=str(value),
                                                   bins = nb,
                                                   density=True
            )
        ax[1].legend()
        ax[1].set_title("Histogram")
        plt.tight_layout()
        plt.savefig("tarea/3-{0}Hist.pdf".format(col))
        plt.show()
        plt.close()
        """
        hist = df.hist(column="Crash_Score",
                        by=col, 
                        figsize=(8,8),
                        bins=nb,
                        sharex=True,
                        sharey=True,
                        density = True,
        )
        for a in hist.flat:
            a.grid()
        plt.tight_layout()
        plt.show()
        plt.close() 
        """

# %%
df1 = df[["Crash_Score","year","Month","Time_of_Day"]]
df1["time"]=(df1["year"]-df1["year"].min())*12*6 + (df1["Month"]-1)*6 + df["Time_of_Day"]-1
df1.plot.scatter(y="Crash_Score",x="time",figsize=(14,6),alpha=0.3)
times = list(set(df1["time"]))
cs_avg = []
for t in times:
    avg = df1[df1["time"]==t]["Crash_Score"].mean()
    cs_avg.append(avg)
plt.plot(times,cs_avg,color = "C1",alpha=0.8)
plt.grid()
plt.title("Serie de tiempo",fontsize=24)
plt.xlabel("Tiempo",fontsize=20)
plt.ylabel("Crash_Score",fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.tight_layout()
plt.savefig("tarea/3-timeplot.pdf")
plt.show()
# Out:
# /home/aldo/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
refers = {
    "year":"2014",
    "Month":"10",
    "Time_of_Day":"4",
    "Rd_Feature":"NONE",
    "Rd_Character":"STRAIGHT-LEVEL",
    "Rd_Class":"OTHER",
    "Rd_Configuration":"TWO-WAY-UNPROTECTED-MEDIAN",
    "Rd_Surface":"SMOOTH ASPHALT",
    "Rd_Conditions":"OTHER",
    "Light":"DAYLIGHT",
    "Weather":"CLEAR",
    "Traffic_Control":"NONE",
    "Work_Area":"NO"
}

# %%
cols = df.columns.tolist()
model = "Crash_Score ~ "
for col in cols:
    if col != "Crash_Score":
        if col == "year" or col =="Month" or col=="Time_of_Day":
            model+=(" + C({0},Treatment({1}))".format(col,refers[col]))
        else:
            model+=(" + C({0},Treatment('{1}'))".format(col,refers[col]))

# %%
print("Model to try:")
print()
print(model)
# Out:
# Model to try:
#
# Crash_Score ~  + C(year,Treatment(2014)) + C(Month,Treatment(10)) + C(Time_of_Day,Treatment(4)) + C(Rd_Feature,Treatment('NONE')) + C(Rd_Character,Treatment('STRAIGHT-LEVEL')) + C(Rd_Class,Treatment('OTHER')) + C(Rd_Configuration,Treatment('TWO-WAY-UNPROTECTED-MEDIAN')) + C(Rd_Surface,Treatment('SMOOTH ASPHALT')) + C(Rd_Conditions,Treatment('OTHER')) + C(Light,Treatment('DAYLIGHT')) + C(Weather,Treatment('CLEAR')) + C(Traffic_Control,Treatment('NONE')) + C(Work_Area,Treatment('NO'))

# %%
models = []
mod = smf.ols(formula=model,data=df)
models.append(mod.fit())

# %%
print(models[-1].summary().tables[0])
print(anovaTable(models[-1]))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Crash_Score   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     6.929
# Date:                Fri, 21 Feb 2020   Prob (F-statistic):           2.27e-52
# Time:                        12:58:32   Log-Likelihood:                -66264.
# No. Observations:               23137   AIC:                         1.326e+05
# Df Residuals:                   23078   BIC:                         1.331e+05
# Df Model:                          58
# Covariance Type:            nonrobust
# ==============================================================================
#                        df         sum_sq      mean_sq          F     $P (> F$)
# Variable
# year                  5.0      61.580005    12.316001   0.682658  6.365513e-01
# Month                11.0     101.759129     9.250830   0.512760  8.962264e-01
# Time_of_Day           5.0     751.259169   150.251834   8.328239  7.075729e-08
# Rd_Feature            4.0    2485.742244   621.435561  34.445265  1.028137e-28
# Rd_Character          6.0     292.039993    48.673332   2.697892  1.280433e-02
# Rd_Class              2.0    2045.586250  1022.793125  56.691927  2.749753e-25
# Rd_Configuration      4.0      17.112595     4.278149   0.237132  9.174949e-01
# Rd_Surface            4.0     188.285577    47.071394   2.609099  3.371148e-02
# Rd_Conditions         3.0      20.426377     6.808792   0.377401  7.693069e-01
# Light                 5.0     661.089802   132.217960   7.328648  7.148647e-07
# Weather               4.0     119.562052    29.890513   1.656787  1.569932e-01
# Traffic_Control       4.0     400.335657   100.083914   5.547505  1.845172e-04
# Work_Area             1.0     105.691631   105.691631   5.858333  1.551114e-02
# Residual          23078.0  416355.921967    18.041248        NaN           NaN

# %%
import scipy.stats as st

# %%
st.boxcox_normplot(df["Crash_Score"],-3.0,4.0,plot=plt)
plt.grid()
plt.tight_layout()
plt.savefig("tarea/3-boxcox.pdf")
plt.show()

# %%
st.boxcox_normmax(df["Crash_Score"],brack=(-3.0,4.0))
# Out:
# 0.27002436675751745

# %%
lmax = st.boxcox(df["Crash_Score"])[1]
df1 = df.copy()
df1["Crash_Score"] = st.boxcox(df1["Crash_Score"],lmax)
df1.rename(columns={'Crash_Score':'Crash_Score_boxcox_0_27'}, inplace=True)

# %%
cols = df1.columns.tolist()
model = "Crash_Score_boxcox_0_27 ~ "
for col in cols:
    if col != "Crash_Score_boxcox_0_27":
        if col == "year" or col =="Month" or col=="Time_of_Day":
            model+=(" + C({0},Treatment({1}))".format(col,refers[col]))
        else:
            model+=(" + C({0},Treatment('{1}'))".format(col,refers[col]))

# %%
print("Model to try:")
print()
print(model)
# Out:
# Model to try:
#
# Crash_Score_boxcox_0_27 ~  + C(year,Treatment(2014)) + C(Month,Treatment(10)) + C(Time_of_Day,Treatment(4)) + C(Rd_Feature,Treatment('NONE')) + C(Rd_Character,Treatment('STRAIGHT-LEVEL')) + C(Rd_Class,Treatment('OTHER')) + C(Rd_Configuration,Treatment('TWO-WAY-UNPROTECTED-MEDIAN')) + C(Rd_Surface,Treatment('SMOOTH ASPHALT')) + C(Rd_Conditions,Treatment('OTHER')) + C(Light,Treatment('DAYLIGHT')) + C(Weather,Treatment('CLEAR')) + C(Traffic_Control,Treatment('NONE')) + C(Work_Area,Treatment('NO'))

# %%
mod = smf.ols(formula=model,data=df1)
models.append(mod.fit())
print(models[-1].summary().tables[0])
print(anovaTable(models[-1]))
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Crash_Score_boxcox_0_27   R-squared:                       0.020
# Model:                                 OLS   Adj. R-squared:                  0.017
# Method:                      Least Squares   F-statistic:                     8.037
# Date:                     Fri, 21 Feb 2020   Prob (F-statistic):           2.60e-64
# Time:                             12:58:34   Log-Likelihood:                -33772.
# No. Observations:                    23137   AIC:                         6.766e+04
# Df Residuals:                        23078   BIC:                         6.814e+04
# Df Model:                               58
# Covariance Type:                 nonrobust
# ===================================================================================
#                        df        sum_sq    mean_sq          F     $P (> F$)
# Variable
# year                  5.0      2.600136   0.520027   0.478126  7.928638e-01
# Month                11.0      4.538950   0.412632   0.379384  9.645587e-01
# Time_of_Day           5.0     69.294798  13.858960  12.742280  2.157787e-12
# Rd_Feature            4.0    165.833943  41.458486  38.117988  7.674077e-32
# Rd_Character          6.0     30.655249   5.109208   4.697536  8.726507e-05
# Rd_Class              2.0    111.077761  55.538881  51.063861  7.450275e-23
# Rd_Configuration      4.0      0.975760   0.243940   0.224285  9.249679e-01
# Rd_Surface            4.0     15.973678   3.993419   3.671652  5.406960e-03
# Rd_Conditions         3.0      1.427820   0.475940   0.437591  7.261040e-01
# Light                 5.0     55.862620  11.172524  10.272303  7.479773e-10
# Weather               4.0      8.619591   2.154898   1.981268  9.440012e-02
# Traffic_Control       4.0     38.088921   9.522230   8.754981  4.656575e-07
# Work_Area             1.0      2.071236   2.071236   1.904347  1.676059e-01
# Residual          23078.0  25100.457694   1.087636        NaN           NaN

# %%
necesary = ["Time_of_Day",
"Rd_Feature",
"Rd_Character",
"Rd_Class",
"Rd_Surface",
"Light",
"Traffic_Control"]
model = "Crash_Score_boxcox_0_27 ~ "
model1= ""
for col in necesary:
    if col == "year" or col =="Month" or col=="Time_of_Day":
        model+=(" + C({0},Treatment({1}))".format(col,refers[col]))  
    else:
        model+=(" + C({0},Treatment('{1}'))".format(col,refers[col]))
model1 = model1[1:]

# %%
print("Model to try:")
print()
print(model)
# Out:
# Model to try:
#
# Crash_Score_boxcox_0_27 ~  + C(Time_of_Day,Treatment(4)) + C(Rd_Feature,Treatment('NONE')) + C(Rd_Character,Treatment('STRAIGHT-LEVEL')) + C(Rd_Class,Treatment('OTHER')) + C(Rd_Surface,Treatment('SMOOTH ASPHALT')) + C(Light,Treatment('DAYLIGHT')) + C(Traffic_Control,Treatment('NONE'))

# %%
mod = smf.ols(formula=model,data=df1)
models.append(mod.fit())
models[-1].summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
necesary = [#"Time_of_Day",
#"Rd_Feature",
#"Rd_Character",
"Rd_Class",
#"Rd_Surface",
#"Light",
"Traffic_Control"]
inter1 = "Time_of_Day*Light"
inter2 = "Rd_Feature*Rd_Character*Rd_Surface"
model = "Crash_Score_boxcox_0_27 ~ "
model1= ""
for col in necesary:
    if col == "year" or col =="Month" or col=="Time_of_Day":
        model+=(" + C({0},Treatment({1}))".format(col,refers[col]))  
    else:
        model+=(" + C({0},Treatment('{1}'))".format(col,refers[col]))
        
model1 = inter1 + " + " + inter2
model += " + " + model1

# %%
print("Model to try:")
print()
print(model)
# Out:
# Model to try:
#
# Crash_Score_boxcox_0_27 ~  + C(Rd_Class,Treatment('OTHER')) + C(Traffic_Control,Treatment('NONE')) + Time_of_Day*Light + Rd_Feature*Rd_Character*Rd_Surface

# %%
mod = smf.ols(formula=model,data=df1)
models.append(mod.fit())

# %%
models[-1].summary().tables[0]
# Out:
# /home/aldo/.local/lib/python3.6/site-packages/statsmodels/base/model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
sm.stats.anova_lm(models[-1])
# Out:
#                                             df        sum_sq    mean_sq  \
# C(Rd_Class, Treatment('OTHER'))            2.0    174.934359  87.467179
# C(Traffic_Control, Treatment('NONE'))      4.0    112.333361  28.083340
# Time_of_Day                                5.0     65.106368  13.021274
# Light                                      5.0     51.474019  10.294804
# Rd_Feature                                 4.0     39.806447   9.951612
# Rd_Character                               6.0     23.666376   3.944396
# Rd_Surface                                 4.0     13.154348   3.288587
# Time_of_Day:Light                         25.0     41.899394   1.675976
# Rd_Feature:Rd_Character                   24.0     39.140794   1.630866
# Rd_Feature:Rd_Surface                     16.0     30.549381   1.909336
# Rd_Character:Rd_Surface                   24.0     18.259287   0.760804
# Rd_Feature:Rd_Character:Rd_Surface        96.0    120.380615   1.253965
# Residual                               22979.0  24934.446573   1.085097
#
#                                                F        PR(>F)
# C(Rd_Class, Treatment('OTHER'))        80.607697  1.302425e-35
# C(Traffic_Control, Treatment('NONE'))  25.880947  1.954280e-21
# Time_of_Day                            12.000100  1.258888e-11
# Light                                   9.487449  4.727582e-09
# Rd_Feature                              9.171172  2.119462e-07
# Rd_Character                            3.635063  1.315107e-03
# Rd_Surface                              3.030684  1.648039e-02
# Time_of_Day:Light                       1.544540  4.037878e-02
# Rd_Feature:Rd_Character                 1.502968  5.415360e-02
# Rd_Feature:Rd_Surface                   1.759599  3.038197e-02
# Rd_Character:Rd_Surface                 0.701139  8.558537e-01
# Rd_Feature:Rd_Character:Rd_Surface      1.155624  1.419221e-01
# Residual                                     NaN           NaN

# %%
necesary = [#"Time_of_Day",
#"Rd_Feature",
#"Rd_Character",
"Rd_Class",
#"Rd_Surface",
#"Light",
"Traffic_Control"]
inter1 = "Rd_Feature*Rd_Character*Rd_Surface*Time_of_Day"
inter2 = "Rd_Feature*Rd_Character*Rd_Surface*Light"
model = "Crash_Score_boxcox_0_27 ~ "
model1= ""
for col in necesary:
    if col == "year" or col =="Month" or col=="Time_of_Day":
        model+=(" + C({0},Treatment({1}))".format(col,refers[col]))  
    else:
        model+=(" + C({0},Treatment('{1}'))".format(col,refers[col]))
        
model1 = inter1 + " + " + inter2
model += " + " + model1
print("Model to try:")
print()
print(model)
# Out:
# Model to try:
#
# Crash_Score_boxcox_0_27 ~  + C(Rd_Class,Treatment('OTHER')) + C(Traffic_Control,Treatment('NONE')) + Rd_Feature*Rd_Character*Rd_Surface*Time_of_Day + Rd_Feature*Rd_Character*Rd_Surface*Light

# %%
mod = smf.ols(formula=model,data=df1)
models.append(mod.fit())

# %%
models[-1].summary().tables[0]
# Out:
# /home/aldo/.local/lib/python3.6/site-packages/statsmodels/base/model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
tab = sm.stats.anova_lm(models[-1])
print(tab)
# Out:
#                                                      df        sum_sq  \
# C(Rd_Class, Treatment('OTHER'))                     2.0    174.934359
# C(Traffic_Control, Treatment('NONE'))               4.0    112.333361
# Rd_Feature                                          4.0     40.449706
# Rd_Character                                        6.0     29.547703
# Rd_Surface                                          4.0     13.397930
# Time_of_Day                                         5.0     61.254468
# Light                                               5.0     48.557752
# Rd_Feature:Rd_Character                            24.0     39.909129
# Rd_Feature:Rd_Surface                              16.0     26.095532
# Rd_Character:Rd_Surface                            24.0     22.641618
# Rd_Feature:Time_of_Day                             20.0     27.731746
# Rd_Character:Time_of_Day                           30.0     38.742048
# Rd_Surface:Time_of_Day                             20.0     30.823596
# Rd_Feature:Light                                   20.0     30.382042
# Rd_Character:Light                                 30.0     50.485889
# Rd_Surface:Light                                   20.0     18.992249
# Rd_Feature:Rd_Character:Rd_Surface                 96.0    106.967889
# Rd_Feature:Rd_Character:Time_of_Day               120.0    127.765453
# Rd_Feature:Rd_Surface:Time_of_Day                  80.0    111.822518
# Rd_Character:Rd_Surface:Time_of_Day               120.0    120.329811
# Rd_Feature:Rd_Character:Light                     120.0    135.303395
# Rd_Feature:Rd_Surface:Light                        80.0     82.238933
# Rd_Character:Rd_Surface:Light                     120.0    124.291854
# Rd_Feature:Rd_Character:Rd_Surface:Time_of_Day    480.0    484.309314
# Rd_Feature:Rd_Character:Rd_Surface:Light          480.0    594.191281
# Residual                                        22481.0  24361.599316
#
#                                                   mean_sq          F  \
# C(Rd_Class, Treatment('OTHER'))                 87.467179  80.715130
# C(Traffic_Control, Treatment('NONE'))           28.083340  25.915440
# Rd_Feature                                      10.112426   9.331795
# Rd_Character                                     4.924617   4.544460
# Rd_Surface                                       3.349482   3.090918
# Time_of_Day                                     12.250894  11.305183
# Light                                            9.711550   8.961865
# Rd_Feature:Rd_Character                          1.662880   1.534514
# Rd_Feature:Rd_Surface                            1.630971   1.505068
# Rd_Character:Rd_Surface                          0.943401   0.870575
# Rd_Feature:Time_of_Day                           1.386587   1.279549
# Rd_Character:Time_of_Day                         1.291402   1.191712
# Rd_Surface:Time_of_Day                           1.541180   1.422208
# Rd_Feature:Light                                 1.519102   1.401835
# Rd_Character:Light                               1.682863   1.552954
# Rd_Surface:Light                                 0.949612   0.876307
# Rd_Feature:Rd_Character:Rd_Surface               1.114249   1.028234
# Rd_Feature:Rd_Character:Time_of_Day              1.064712   0.982521
# Rd_Feature:Rd_Surface:Time_of_Day                1.397781   1.289879
# Rd_Character:Rd_Surface:Time_of_Day              1.002748   0.925341
# Rd_Feature:Rd_Character:Light                    1.127528   1.040488
# Rd_Feature:Rd_Surface:Light                      1.027987   0.948631
# Rd_Character:Rd_Surface:Light                    1.035765   0.955809
# Rd_Feature:Rd_Character:Rd_Surface:Time_of_Day   1.008978   0.931089
# Rd_Feature:Rd_Character:Rd_Surface:Light         1.237899   1.142339
# Residual                                         1.083653        NaN
#
#                                                       PR(>F)
# C(Rd_Class, Treatment('OTHER'))                 1.177938e-35
# C(Traffic_Control, Treatment('NONE'))           1.831474e-21
# Rd_Feature                                      1.563890e-07
# Rd_Character                                    1.298451e-04
# Rd_Surface                                      1.486040e-02
# Time_of_Day                                     6.537667e-11
# Light                                           1.617508e-08
# Rd_Feature:Rd_Character                         4.564229e-02
# Rd_Feature:Rd_Surface                           8.786442e-02
# Rd_Character:Rd_Surface                         6.449523e-01
# Rd_Feature:Time_of_Day                          1.799008e-01
# Rd_Character:Time_of_Day                        2.165380e-01
# Rd_Surface:Time_of_Day                          9.943929e-02
# Rd_Feature:Light                                1.086807e-01
# Rd_Character:Light                              2.739920e-02
# Rd_Surface:Light                                6.185803e-01
# Rd_Feature:Rd_Character:Rd_Surface              4.047407e-01
# Rd_Feature:Rd_Character:Time_of_Day             5.370705e-01
# Rd_Feature:Rd_Surface:Time_of_Day               4.191133e-02
# Rd_Character:Rd_Surface:Time_of_Day             7.084533e-01
# Rd_Feature:Rd_Character:Light                   3.627185e-01
# Rd_Feature:Rd_Surface:Light                     6.092508e-01
# Rd_Character:Rd_Surface:Light                   6.193246e-01
# Rd_Feature:Rd_Character:Rd_Surface:Time_of_Day  8.556943e-01
# Rd_Feature:Rd_Character:Rd_Surface:Light        1.765626e-02
# Residual                                                 NaN

# %%
sm.graphics.qqplot(models[-1].resid)
plt.title("Q-Q plot of predicted values")
plt.grid()
plt.tight_layout()
plt.savefig("tarea/3-qqplot4.pdf")
plt.show()

# %%
model = ""
for var in tab.index.tolist():
    if tab.loc[var,"PR(>F)"]<= 0.5:
        model += "+ " + var
model = "Crash_Score_boxcox_0_27 ~ " + model

# %%
print("Model to try:")
print()
print(model)
# Out:
# Model to try:
#
# Crash_Score_boxcox_0_27 ~ + C(Rd_Class, Treatment('OTHER'))+ C(Traffic_Control, Treatment('NONE'))+ Rd_Feature+ Rd_Character+ Rd_Surface+ Time_of_Day+ Light+ Rd_Feature:Rd_Character+ Rd_Feature:Rd_Surface+ Rd_Feature:Time_of_Day+ Rd_Character:Time_of_Day+ Rd_Surface:Time_of_Day+ Rd_Feature:Light+ Rd_Character:Light+ Rd_Feature:Rd_Character:Rd_Surface+ Rd_Feature:Rd_Surface:Time_of_Day+ Rd_Feature:Rd_Character:Light+ Rd_Feature:Rd_Character:Rd_Surface:Light

# %%
mod = smf.ols(formula=model,data=df1)
models.append(mod.fit())

# %%
models[-1].summary().tables[0]
# Out:
# /home/aldo/.local/lib/python3.6/site-packages/statsmodels/base/model.py:1362: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /home/aldo/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model = ""
for var in tab.index.tolist():
    if tab.loc[var,"PR(>F)"]<= 0.1:
        model += "+ " + var
model = "Crash_Score_boxcox_0_27 ~ " + model

# %%
print("Model to try:")
print()
print(model)
# Out:
# Model to try:
#
# Crash_Score_boxcox_0_27 ~ + C(Rd_Class, Treatment('OTHER'))+ C(Traffic_Control, Treatment('NONE'))+ Rd_Feature+ Rd_Character+ Rd_Surface+ Time_of_Day+ Light+ Rd_Feature:Rd_Character+ Rd_Feature:Rd_Surface+ Rd_Surface:Time_of_Day+ Rd_Character:Light+ Rd_Feature:Rd_Surface:Time_of_Day+ Rd_Feature:Rd_Character:Rd_Surface:Light

# %%
mod = smf.ols(formula=model,data=df1)
models.append(mod.fit())

# %%
models[-1].summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
for model in models:
    i = models.index(model)
    coefficientTable(model).to_latex(buf="tarea/3-mod{0}Cof.tex".format(i),column_format="p{4cm}cccccc",longtable=True,float_format = "%.4f")
    anovaTable(model).to_latex(buf="tarea/3-mod{0}Anova.tex".format(i),column_format="p{6cm}lccccc",longtable=True,float_format = "%.4f")

# %%
tab = comparisonTable(models).drop("Model",axis="columns")
tab.index.name="model"
tab.to_latex(buf="tarea/3-comparison.tex",column_format="lrrrrrr")
